# %% [markdown]
# # Training

# %%
# !python -m pipeline_train_predict.train --yaml_path configs/config_baseline.yaml
# Out:
# Data mode: zarr
# Preparing data samplers
# Train: 2 surveys, 578 raw files, 3364714 pings
# Validation: 1 surveys, 391 raw files, 1500745 pings
# Executed time for preparing samples (s): 5.29
#
# Preparing data loaders
# Executed time for preparing dataloaders (s): 5.29
#
# Start training
#  - Copying source for backup - FINISHED
# Training model: 100%|███████████████████████| 1000/1000 [43:56<00:00,  2.64s/it]
# Training complete
# Trained model parameters saved to file: saved_models/config_baseline/2023-02-23_092837/last.pt
# Executed time for training (h): 0.73

# %% [markdown]
# # Prediction

# %%
# !python -m pipeline_train_predict.evaluate --yaml_path configs/config_baseline.yaml --checkpoint_path saved_models/config_baseline/2023-02-23_092837/last.pt --save_path_metrics metrics --save_path_plot metrics
# Out:
# loaded model /home/a39083/UNET_NR/CRIMAC-classifiers-unet/crimac_unet/saved_models/config_baseline/2023-02-23_092837/last.pt
#
# Loading zarr data partition object...
# Executed time for loading data partition object (min): 0.0
#
# Metrics directory: /home/a39083/UNET_NR/CRIMAC-classifiers-unet/crimac_unet/metrics/config_baseline/2023-02-23_092837
# Plot directory: /home/a39083/UNET_NR/CRIMAC-classifiers-unet/crimac_unet/metrics/config_baseline/2023-02-23_092837
#
# Running evaluation for 2017
# Evaluating model: 100%|███████████████████| 1737/1737 [1:17:29<00:00,  2.68s/it]
# F1 score: 0.2646173078568151

# %% [markdown]
# # Save Predictions

# %%
# !python -m pipeline_train_predict.save_predict --yaml_path configs/config_baseline.yaml --checkpoint_path saved_models/config_baseline/2023-02-23_092837/last.pt --save_predictions_path [predictions]

# %% [markdown]
# # Tests for Code

# %%
import xarray as xr
print(xr.__version__)
# Out:
# 0.20.0

# %%
survey = xr.open_zarr('/data/2017/2017843/ACOUSTIC/GRIDDED/2017843_sv.zarr')

# %%
survey.sv
# Out:
# <xarray.DataArray 'sv' (frequency: 6, ping_time: 1500745, range: 709)>
# dask.array<open_dataset-aca8808c8fd08a923996ac380a197946sv, shape=(6, 1500745, 709), dtype=float64, chunksize=(1, 3943, 709), chunktype=numpy.ndarray>
# Coordinates:
#   * frequency  (frequency) float32 18.0 38.0 70.0 120.0 200.0 333.0
#   * ping_time  (ping_time) datetime64[ns] 2017-04-26T06:34:57.001319 ... 2017...
#   * range      (range) float64 0.0 0.19 0.3801 0.5701 ... 134.2 134.4 134.5
#     raw_file   (ping_time) <U29 dask.array<chunksize=(3943,), meta=np.ndarray>
